# %%
import cv2
import numpy as np
from ultralytics import YOLO 
import matplotlib.pyplot as plt 
from PIL import Image
import os
import MyUtils
import Paths

# %%
Path=Paths.ProjectPath()

# %%
model=YOLO(os.path.join(Path.Yolo_Training_Logs_Path,"resultx-2//weights//best.pt"))

# %%
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT,640)
cap.set(cv2.CAP_PROP_FRAME_WIDTH,640)
while True:
    ret, frame = cap.read()
    if not ret:
        break

    height, width = frame.shape[:2]
    
    
    res=model.predict(frame)
    try:

        masks=res[0].masks.data
        boxes=res[0].boxes.xywhn.numpy()
        scores=res[0].boxes.conf
        n=masks.shape[0]

        r,g,b=cv2.split(frame)
        
        for m in range(n):
            
            #mask=cv2.resize(masks[m,:,:].numpy().astype(np.uint8),(width,height))
            mask=masks[m,:,:].numpy().astype(np.uint8)
            for i in range(height):
                for j in range(width):
                    if mask[i][j]>0:
                            b[i][j]=255
                        
        
        frame=cv2.merge([r,g,b])

        for i in range(n):
            box=list(boxes[i])
            confidence=scores[i]
            x,y,w,h=box
            # print("xywh:",x,y,w,h)
            x = x* width
            y= y * height
            bwidth = w* width
            bheight = h * height

            x = int(x - (bwidth / 2))
            y = int(y - (bheight/ 2))
            
            w = int(bwidth)
            h = int(bheight)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255,0), 4)
            cv2.putText(frame, str(confidence), (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        #frame=MyUtils.display_instances_real_time(frame,MyUtils.convertYOLO_bb_2_MRCNN_bb(boxes,height,width),masks,np.ones(len(boxes),dtype=np.int32),['Background','Grapes'],scores)
        # print("done")
    except Exception as e:
        print(e)
 
    cv2.imshow('ViniScope', frame)
   
 
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 1068.0ms
# Speed: 2.0ms preprocess, 1068.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1156.7ms
# Speed: 2.0ms preprocess, 1156.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1076.7ms
# Speed: 1.0ms preprocess, 1076.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1041.1ms
# Speed: 1.0ms preprocess, 1041.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1078.5ms
# Speed: 2.0ms preprocess, 1078.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1070.2ms
# Speed: 1.0ms preprocess, 1070.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 5 Grapess, 1075.9ms
# Speed: 2.0ms preprocess, 1075.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Grapes, 1072.6ms
# Speed: 1.0ms preprocess, 1072.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Grapess, 1056.0ms
# Speed: 1.0ms preprocess, 1056.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Grapess, 1036.8ms
# Speed: 1.0ms preprocess, 1036.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 Grapess, 1067.5ms
# Speed: 1.0ms preprocess, 1067.5ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1031.6ms
# Speed: 1.0ms preprocess, 1031.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 1 Grapes, 1078.4ms
# Speed: 1.0ms preprocess, 1078.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Grapes, 1036.5ms
# Speed: 1.0ms preprocess, 1036.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Grapes, 1007.9ms
# Speed: 2.0ms preprocess, 1007.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1047.4ms
# Speed: 1.0ms preprocess, 1047.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1018.6ms
# Speed: 1.0ms preprocess, 1018.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1008.8ms
# Speed: 1.0ms preprocess, 1008.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1021.0ms
# Speed: 1.0ms preprocess, 1021.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 1 Grapes, 1003.2ms
# Speed: 1.3ms preprocess, 1003.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 Grapess, 1017.5ms
# Speed: 1.0ms preprocess, 1017.5ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 Grapess, 1007.7ms
# Speed: 1.0ms preprocess, 1007.7ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 Grapess, 985.9ms
# Speed: 1.0ms preprocess, 985.9ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 976.3ms
# Speed: 1.0ms preprocess, 976.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1011.3ms
# Speed: 1.0ms preprocess, 1011.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 1 Grapes, 1009.5ms
# Speed: 1.0ms preprocess, 1009.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Grapes, 970.5ms
# Speed: 1.0ms preprocess, 970.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1064.3ms
# Speed: 1.0ms preprocess, 1064.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 1 Grapes, 1019.8ms
# Speed: 2.0ms preprocess, 1019.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Grapes, 1000.5ms
# Speed: 1.0ms preprocess, 1000.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1016.7ms
# Speed: 1.0ms preprocess, 1016.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 999.3ms
# Speed: 1.0ms preprocess, 999.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 987.5ms
# Speed: 2.0ms preprocess, 987.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 995.1ms
# Speed: 2.0ms preprocess, 995.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1016.9ms
# Speed: 1.0ms preprocess, 1016.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 1 Grapes, 1113.1ms
# Speed: 1.0ms preprocess, 1113.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1022.9ms
# Speed: 1.0ms preprocess, 1022.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 1 Grapes, 1044.5ms
# Speed: 2.0ms preprocess, 1044.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1010.4ms
# Speed: 1.0ms preprocess, 1010.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1064.0ms
# Speed: 1.0ms preprocess, 1064.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1009.4ms
# Speed: 1.0ms preprocess, 1009.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1058.3ms
# Speed: 1.0ms preprocess, 1058.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1016.8ms
# Speed: 1.0ms preprocess, 1016.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1009.6ms
# Speed: 1.0ms preprocess, 1009.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1064.7ms
# Speed: 1.8ms preprocess, 1064.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1015.2ms
# Speed: 1.0ms preprocess, 1015.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1047.7ms
# Speed: 1.0ms preprocess, 1047.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1162.6ms
# Speed: 2.0ms preprocess, 1162.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
#
# 0: 480x640 (no detections), 1176.6ms
# Speed: 2.0ms preprocess, 1176.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 'NoneType' object has no attribute 'data'
